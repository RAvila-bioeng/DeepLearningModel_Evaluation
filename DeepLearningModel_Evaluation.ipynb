# %% [markdown]
# <a href="https://colab.research.google.com/github/RAvila-bioeng/DeepLearningModel_Evaluation/blob/main/DeepLearningModel_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import tensorflow as tf
from tensorflow.keras.layers import (Dense, Conv2D, MaxPooling2D, Dropout,
    BatchNormalization, Conv2DTranspose, Activation, concatenate, Input)
from tensorflow.keras import Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
import pandas as pd
import time
from google.colab import drive
import gc

# %%
drive.mount('/content/drive')
SAVE_DIR = "/content/drive/MyDrive/unet_experimentos"
os.makedirs(SAVE_DIR, exist_ok=True)

print("Guardando resultados en:", SAVE_DIR)
download_path = kagglehub.dataset_download(
    "nikitamanaenkov/fundus-image-dataset-for-vessel-segmentation"
)
print("Dataset descargado en:", download_path)
# Out:
# Mounted at /content/drive
# Guardando resultados en: /content/drive/MyDrive/unet_experimentos
# Using Colab cache for faster access to the 'fundus-image-dataset-for-vessel-segmentation' dataset.
# Dataset descargado en: /kaggle/input/fundus-image-dataset-for-vessel-segmentation

# %%
def conv_block(input_tensor, filters, kernel_size=3, activation="relu",
               batch_norm=True, dropout_rate=0.0):

    x = Conv2D(filters, kernel_size, padding="same")(input_tensor)
    if batch_norm:
        x = BatchNormalization()(x)
    x = Activation(activation)(x)

    x = Conv2D(filters, kernel_size, padding="same")(x)
    if batch_norm:
        x = BatchNormalization()(x)
    x = Activation(activation)(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    return x


def encoder_block(input_tensor, filters, **kwargs):
    x = conv_block(input_tensor, filters, **kwargs)
    p = MaxPooling2D((2,2))(x)
    return x, p


def decoder_block(input_tensor, skip_tensor, filters, **kwargs):
    x = Conv2DTranspose(filters, 2, strides=2, padding="same")(input_tensor)
    x = concatenate([x, skip_tensor])
    x = conv_block(x, filters, **kwargs)
    return x

# %%
def build_model(img_size=(512,512),
                filters_first_layer=64,
                activation="relu",
                kernel_size=3,
                batch_norm=True,
                dropout_rate=0.0,
                unet_depth=4):
    """
    Misma arquitectura que el notebook original:
    4 bloques de encoder, bottleneck, 4 bloques de decoder.
    Solo hacemos algunos parámetros configurables.
    """
    inp = Input(shape=(*img_size, 3))

    # --- Encoder ---
    x1, p1 = encoder_block(
        inp,
        filters_first_layer,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    x2, p2 = encoder_block(
        p1,
        filters_first_layer * 2,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    x3, p3 = encoder_block(
        p2,
        filters_first_layer * 4,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    x4, p4 = encoder_block(
        p3,
        filters_first_layer * 8,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    # --- Bottleneck ---
    b = conv_block(
        p4,
        filters_first_layer * 16,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    # --- Decoder ---
    d1 = decoder_block(
        b, x4,
        filters_first_layer * 8,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    d2 = decoder_block(
        d1, x3,
        filters_first_layer * 4,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    d3 = decoder_block(
        d2, x2,
        filters_first_layer * 2,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    d4 = decoder_block(
        d3, x1,
        filters_first_layer,
        activation=activation,
        kernel_size=kernel_size,
        batch_norm=batch_norm,
        dropout_rate=dropout_rate
    )

    out = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = Model(inp, out)

    return model

# %%
test_model = build_model()
print(test_model is None)
test_model.summary()
# Out:
# False
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512, 512,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 128,  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 32,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 256,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 256, 256,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 512,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 512, 512,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 512, 512,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 512, 512,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
def load_data(path, img_size=(512,512), num_images=100):
    images, masks = [], []

    originals = sorted(os.listdir(path + "/Original"))[:num_images]
    grounds   = sorted(os.listdir(path + "/Ground truth"))[:num_images]

    for img_file, mask_file in zip(originals, grounds):

        img = load_img(os.path.join(path, "Original", img_file),
                       target_size=img_size)
        mask = load_img(os.path.join(path, "Ground truth", mask_file),
                        target_size=img_size, color_mode="grayscale")

        images.append(img_to_array(img)/255)
        masks.append(img_to_array(mask)/255)

    return np.array(images), np.array(masks)


def augment(image, mask, level="medium"):

    if level in ["medium", "strong"]:
        image = tf.image.random_flip_left_right(image)
        mask  = tf.image.random_flip_left_right(mask)

    if level == "strong":
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_contrast(image, 0.8, 1.2)

    return image, mask


def tf_dataset(x, y, batch_size=8, shuffle_size=8, aug_level="medium"):

    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(shuffle_size).batch(batch_size)

    def aug_fn(img, mask):
        return augment(img, mask, aug_level)

    if aug_level != "none":
        ds = ds.map(aug_fn, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
def save_epoch_results(parameter, value, history, save_dir, config):
    """Guarda un CSV con los resultados por época."""
    rows = []

    epochs = len(history.history["loss"])

    for e in range(epochs):
        rows.append({
            "parameter": parameter,
            "value": value,
            "epoch": e+1,
            "train_loss": history.history["loss"][e],
            "train_acc": history.history["accuracy"][e],
            "val_loss": history.history["val_loss"][e],
            "val_acc": history.history["val_accuracy"][e],
            **config
        })

    df = pd.DataFrame(rows)
    df.to_csv(f"{save_dir}/epochs_{parameter}_{value}.csv", index=False)

# %% [markdown]
# borrar

# %%
base_config = {
    "filters_first_layer": 64,
    "kernel_size": 3,
    "activation": "relu",
    "batch_norm": True,
    "dropout_rate": 0.0,
    "batch_size": 8,
    "learning_rate": 1e-3,
    "optimizer": "adam",
    "epochs": 10,
    "shuffle_size": 8,
    "data_augmentation": "medium",
    "threshold": 0.5,
    "unet_depth" : 100,
    "img_size": (512, 512)
}

# %%
parameters_change = [
    {"param": "filters_first_layer", "values": [32, 64, 128]},
    {"param": "unet_depth", "values": [3, 4, 5]},
    {"param": "kernel_size", "values": [3, 5, 7]},
    {"param": "activation", "values": ["relu", "elu", "leaky_relu"]},
    {"param": "batch_norm", "values": [True, False]},
    {"param": "dropout_rate", "values": [0.0, 0.2, 0.4]},
    {"param": "batch_size", "values": [2, 4, 8]},
    {"param": "learning_rate", "values": [1e-3, 1e-4, 1e-5]},
    {"param": "optimizer", "values": ["adam", "rmsprop", "sgd"]},
    {"param": "epochs", "values": [30, 60, 100]},
    {"param": "shuffle_size", "values":[8, 32, 128]}
    {"param": "image_size", "values":[(256,256), (384,384), (512,512)]}
    {"param": "threshold", "values": [0.3, 0.5, 0.7]}
    {"param": "data_augmentation", "values": ["light", "medium", "strong"]},

]

# %%
for exp in parameters_change:

    param = exp["param"]
    values = exp["values"]

    for value in values:

        print(f"\n\n>>> EXPERIMENTO: {param} = {value}")

#Vaciamos lo anterior antes de cada bucle, si no se queda ocupando espacio y la GPU no llega
        tf.keras.backend.clear_session()
        gc.collect()


        conf = base_config.copy()
        conf[param] = value

        # Cargar datos
        x_train, y_train = load_data(
            f"{download_path}/train",
            img_size=conf["img_size"],
            num_images=100
        )

        x_test, y_test = load_data(
            f"{download_path}/test",
            img_size=conf["img_size"],
            num_images=100
        )

        # Dataset
        train_ds = tf_dataset(x_train, y_train,
                              batch_size=conf["batch_size"],
                              shuffle_size=conf["shuffle_size"],
                              aug_level=conf["data_augmentation"])

        test_ds = tf_dataset(x_test, y_test,
                             batch_size=conf["batch_size"],
                             shuffle_size=1,
                             aug_level="none")

        # Modelo
        model = build_model(
            img_size=conf["img_size"],
            filters_first_layer=conf["filters_first_layer"],
            activation=conf["activation"],
            kernel_size=conf["kernel_size"],
            batch_norm=conf["batch_norm"],
            dropout_rate=conf["dropout_rate"],
            unet_depth=conf["unet_depth"]
        )

        # Optimizador
        if conf["optimizer"] == "adam":
            opt = tf.keras.optimizers.Adam(conf["learning_rate"])
        else:
            opt = tf.keras.optimizers.RMSprop(conf["learning_rate"])

        model.compile(loss="binary_crossentropy",
                      optimizer=opt,
                      metrics=["accuracy"])

        # Callbacks
        checkpoint_path = f"{SAVE_DIR}/best_{param}_{value}.keras"
        checkpoint = tf.keras.callbacks.ModelCheckpoint(
            checkpoint_path, save_best_only=True, monitor="val_loss"
        )

        early = tf.keras.callbacks.EarlyStopping(
            patience=8, restore_best_weights=True, monitor="val_loss"
        )

        # Entrenar
        history = model.fit(
            train_ds,
            epochs=conf["epochs"],
            validation_data=test_ds,
            callbacks=[checkpoint, early],
            verbose=1
        )

        # Guardar métricas por época
        save_epoch_results(param, value, history, SAVE_DIR, conf)

        print(f"✓ DONE: {param}={value}")

print("\n===== TODOS LOS EXPERIMENTOS COMPLETADOS =====\n")
# Out:
# >>> EXPERIMENTO: unet_depth = 4
# Epoch 1/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.8722 - loss: 0.3512 - val_accuracy: 0.9302 - val_loss: 0.3293
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9321 - loss: 0.2269 - val_accuracy: 0.9302 - val_loss: 0.2596
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9325 - loss: 0.2118 - val_accuracy: 0.9302 - val_loss: 0.2495
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 49s 978ms/step - accuracy: 0.9351 - loss: 0.1957 - val_accuracy: 0.9302 - val_loss: 0.2562
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 49s 976ms/step - accuracy: 0.9305 - loss: 0.2073 - val_accuracy: 0.9301 - val_loss: 0.2519
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9318 - loss: 0.2091 - val_accuracy: 0.9302 - val_loss: 0.2486
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9330 - loss: 0.2138 - val_accuracy: 0.9292 - val_loss: 0.2339
# Epoch 8/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 49s 981ms/step - accuracy: 0.9319 - loss: 0.1955 - val_accuracy: 0.9224 - val_loss: 0.2359
# Epoch 9/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9276 - loss: 0.2069 - val_accuracy: 0.9380 - val_loss: 0.1946
# Epoch 10/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9302 - loss: 0.1974 - val_accuracy: 0.9398 - val_loss: 0.1930
# Epoch 11/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9339 - loss: 0.1882 - val_accuracy: 0.9428 - val_loss: 0.1760
# Epoch 12/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9314 - loss: 0.1980 - val_accuracy: 0.9344 - val_loss: 0.1475
# Epoch 13/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 49s 976ms/step - accuracy: 0.9334 - loss: 0.1836 - val_accuracy: 0.9313 - val_loss: 0.1851
# Epoch 14/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9310 - loss: 0.1990 - val_accuracy: 0.9418 - val_loss: 0.1429
# Epoch 15/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9290 - loss: 0.2098 - val_accuracy: 0.9303 - val_loss: 0.1411
# Epoch 16/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 965ms/step - accuracy: 0.9308 - loss: 0.2013 - val_accuracy: 0.9312 - val_loss: 0.1506
# Epoch 17/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 964ms/step - accuracy: 0.9308 - loss: 0.1962 - val_accuracy: 0.9463 - val_loss: 0.1478
# Epoch 18/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9267 - loss: 0.2013 - val_accuracy: 0.9525 - val_loss: 0.1340
# Epoch 19/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9309 - loss: 0.1931 - val_accuracy: 0.9652 - val_loss: 0.1223
# Epoch 20/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 963ms/step - accuracy: 0.9448 - loss: 0.1642 - val_accuracy: 0.9556 - val_loss: 0.1284
# Epoch 21/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 963ms/step - accuracy: 0.9312 - loss: 0.1927 - val_accuracy: 0.9629 - val_loss: 0.1267
# Epoch 22/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 965ms/step - accuracy: 0.9346 - loss: 0.1827 - val_accuracy: 0.9550 - val_loss: 0.1364
# Epoch 23/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 965ms/step - accuracy: 0.9342 - loss: 0.1847 - val_accuracy: 0.9520 - val_loss: 0.1302
# Epoch 24/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.9322 - loss: 0.1888 - val_accuracy: 0.9695 - val_loss: 0.1163
# Epoch 25/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 968ms/step - accuracy: 0.9286 - loss: 0.1964 - val_accuracy: 0.9366 - val_loss: 0.1616
# Epoch 26/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 966ms/step - accuracy: 0.9443 - loss: 0.1626 - val_accuracy: 0.9500 - val_loss: 0.1522
# Epoch 27/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 966ms/step - accuracy: 0.9348 - loss: 0.1850 - val_accuracy: 0.9693 - val_loss: 0.1167
# Epoch 28/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 969ms/step - accuracy: 0.9389 - loss: 0.1741 - val_accuracy: 0.9619 - val_loss: 0.1281
# Epoch 29/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 966ms/step - accuracy: 0.9360 - loss: 0.1831 - val_accuracy: 0.9450 - val_loss: 0.1344
# Epoch 30/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 968ms/step - accuracy: 0.9330 - loss: 0.1888 - val_accuracy: 0.9644 - val_loss: 0.1211
# ✓ DONE: unet_depth=4
#
# ===== TODOS LOS EXPERIMENTOS COMPLETADOS =====
